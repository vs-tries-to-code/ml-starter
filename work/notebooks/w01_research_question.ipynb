# %% [markdown]
# <a href="https://colab.research.google.com/github/vs-tries-to-code/flyrank-ml-starter/blob/w1Research/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# **Lane 2: Refresh / Content Opportunity Scoring** :
# I currently chose this lane because it focuses on a high-impact, practical problem of prioritizing which pages need human intervention. It allows me to use Machine Learning to help editors spend their limited time on the most promising pages first, rather than guessing which pages to fix.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# **Decision**: Which pages should be reviewed first for refresh, expansion, protection, pruning, or monitoring?
#
# **Action:** A human reviewer (editor or SEO specialist) acts on these ranked recommendations to perform site maintenance.
#
# **Cost of a wrong call:**
#
# *  **False Positive** : A page which does not require any refreshing would be flagged and eventually worked on, which costs time and effort that could be dedicated to pages which actually deserve it.
# *   **False Negative** : A page which requires immediate maintanence might not get the required attention on time as it would not be flagged, missing crucial intervention.
#
# In both scenarios, the opportunity cost is high

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import os, sys, subprocess

IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/flyrank-bih/flyrank-ml-internship-starter"
REPO_DIR = "flyrank-ml-internship-starter"

if IN_COLAB:
    # Ensure we are in /content first to prevent nested directory issues
    if os.getcwd() != "/content":
        os.chdir("/content")

    # Clone the repository if it doesn't exist
    if not os.path.isdir(REPO_DIR):
        subprocess.run(["git", "clone", "--depth", "1", REPO_URL], check=True)

    # Change into the cloned repository directory
    if os.getcwd() != os.path.join("/content", REPO_DIR):
        os.chdir(REPO_DIR)

    # Install requirements
    subprocess.run([sys.executable, "-m", "pip", "install", "-q", "-r", "requirements.txt"], check=True)
elif os.path.basename(os.getcwd()) == "notebooks":
    # If not in Colab and in 'notebooks' subdir, move to parent repo root
    os.chdir("..")

print("Working dir:", os.getcwd())
# Out:
# Working dir: /content/flyrank-ml-internship-starter

# %%
import pandas as pd

# %%
csv_file_path = "data/raw/content_refresh_anonymized.csv"
df = pd.read_csv(csv_file_path)
display(df.head())

corr1 = df['content_age_days'].corr(df['ctr'])
print(f"The correlation between the content age and CTR : {corr1}")

corr2 = df['content_age_days'].corr(df['impressions_90d'])
print(f"The correlation between the content age and impressions_90d {corr2}")
# Out:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %% [markdown]
# Intuitively it can be hypothesised that it would be the oldest content which should be prioritised. However, its correlation with CTR and impressions over the 90 day window is weak. It can be concluded that a more nuanced approach is required for accurate prediction.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# **What I can say:** My work provides evidence-backed, ranked action recommendations based on observational signals, serving as a decision-support tool to maximize reviewer efficiency.
#
# **What I cannot say:** I cannot claim that a refresh caused a recovery unless I perform an explicit experiment or causal design. I also cannot claim that this work proves Google's algorithm factors, nor can I predict AI rankings or citations.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
